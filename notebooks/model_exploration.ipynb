# %% [markdown]
# # Customer Churn Model Exploration
#
# This notebook mirrors the production training pipeline at a lightweight exploratory level. The deployable implementation lives in `model/train_model.py`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from model.train_model import generate_customer_churn_data

df = generate_customer_churn_data(n_samples=1000, random_state=42)
df.head()

# %%
df.describe(include='all').T

# %%
df['churned'].value_counts(normalize=True).rename('class_rate')

# %% [markdown]
# The production training script persists three artifacts: `model.pkl`, `metrics.json`, and `model_info.json`. Those artifacts are loaded by the FastAPI prediction service and surfaced in the Streamlit dashboard.
